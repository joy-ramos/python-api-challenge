# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 634

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather"

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lon = []
max_temp = []
wind_speed = []

set = 1

print("Beginning Data Retrieval")
print("-----------------------------")

for city in cities:
    
    # Build partial query URL
    query_url = f"{url}?q={city}&units=imperial&appid={weather_api_key}"
    response = requests.get(query_url).json()
    
    
    try:
        
        
        city_name.append(response['name'])
        
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        humidity.append(response['main']['humidity'])

        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])

        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
    
        print (f"Processing Record {cities.index(city)+1} of Set {set} | {city}")
        
    
    except:
        print("City not found. Skipping...")
        set = set + 1
        pass
    
print("""
-----------------------------
Data Retrieval Complete      
-----------------------------
""")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | port-gentil
# Processing Record 3 of Set 1 | sao filipe
# Processing Record 4 of Set 1 | buala
# Processing Record 5 of Set 1 | gushikawa
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | galveston
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | stornoway
# Processing Record 10 of Set 1 | namibe
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | cabo san lucas
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | platen
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | svetlogorsk
# Processing Record 19 of Set 1 | laguna
# Processing Record 20 of Set 1 | nishihara
# Processing Record 21 of Set 1 | katsuura
# Processing Record 22 of Set 1 | moyobamba
# Processing Record 23 of Set 1 | dmitriyevka
# Processing Record 24 of Set 1 | touros
# Processing Record 25 of Set 1 | lapua
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | hornepayne
# Processing Record 30 of Set 1 | berlevag
# City not found. Skipping...
# Processing Record 32 of Set 2 | ushuaia
# Processing Record 33 of Set 2 | zaoyang
# Processing Record 34 of Set 2 | vestnes
# Processing Record 35 of Set 2 | yelovo
# Processing Record 36 of Set 2 | loiza
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | pierre
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | nanortalik
# Processing Record 41 of Set 2 | punta arenas
# Processing Record 42 of Set 2 | cape town
# Processing Record 43 of Set 2 | quatre cocos
# Processing Record 44 of Set 2 | beloha
# Processing Record 45 of Set 2 | georgetown
# Processing Record 46 of Set 2 | rognan
# Processing Record 47 of Set 2 | sengiley
# Processing Record 48 of Set 2 | klaksvik
# Processing Record 49 of Set 2 | atuona
# Processing Record 50 of Set 2 | sinop
# Processing Record 51 of Set 2 | kapaa
# Processing Record 52 of Set 2 | douglas
# Processing Record 53 of Set 2 | tuktoyaktuk
# Processing Record 54 of Set 2 | emerald
# Processing Record 55 of Set 2 | salinopolis
# City not found. Skipping...
# Processing Record 57 of Set 3 | saint george
# Processing Record 58 of Set 3 | buraydah
# Processing Record 59 of Set 3 | grafton
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 62 of Set 5 | saskylakh
# Processing Record 63 of Set 5 | puerto ayora
# City not found. Skipping...
# Processing Record 65 of Set 6 | kitimat
# Processing Record 66 of Set 6 | bambous virieux
# Processing Record 67 of Set 6 | dvinskoy
# Processing Record 68 of Set 6 | lapeer
# Processing Record 69 of Set 6 | avarua
# Processing Record 70 of Set 6 | bonavista
# Processing Record 71 of Set 6 | umm lajj
# Processing Record 72 of Set 6 | ilhabela
# Processing Record 73 of Set 6 | chute-aux-outardes
# Processing Record 74 of Set 6 | aracaju
# Processing Record 75 of Set 6 | bluff
# Processing Record 76 of Set 6 | severo-kurilsk
# Processing Record 77 of Set 6 | grand gaube
# Processing Record 78 of Set 6 | saldanha
# Processing Record 79 of Set 6 | chenzhou
# Processing Record 80 of Set 6 | cidreira
# Processing Record 81 of Set 6 | hithadhoo
# Processing Record 82 of Set 6 | busselton
# Processing Record 83 of Set 6 | tasiilaq
# Processing Record 84 of Set 6 | pundaguitan
# Processing Record 85 of Set 6 | druzhba
# Processing Record 86 of Set 6 | hermanus
# Processing Record 87 of Set 6 | kodiak
# Processing Record 88 of Set 6 | piracuruca
# Processing Record 89 of Set 6 | bredasdorp
# Processing Record 90 of Set 6 | rochegda
# Processing Record 91 of Set 6 | duldurga
# Processing Record 92 of Set 6 | astana
# Processing Record 93 of Set 6 | narsaq
# Processing Record 94 of Set 6 | caravelas
# Processing Record 95 of Set 6 | ravar
# Processing Record 96 of Set 6 | chokurdakh
# Processing Record 97 of Set 6 | viedma
# Processing Record 98 of Set 6 | vaini
# Processing Record 99 of Set 6 | kaitangata
# Processing Record 100 of Set 6 | florianopolis
# Processing Record 101 of Set 6 | mahebourg
# Processing Record 102 of Set 6 | chuy
# Processing Record 103 of Set 6 | saint-francois
# Processing Record 104 of Set 6 | abha
# Processing Record 105 of Set 6 | bethel
# Processing Record 106 of Set 6 | sorong
# City not found. Skipping...
# Processing Record 108 of Set 7 | hobart
# Processing Record 109 of Set 7 | shilong
# Processing Record 110 of Set 7 | ballarat
# Processing Record 111 of Set 7 | mount gambier
# Processing Record 112 of Set 7 | sangar
# Processing Record 113 of Set 7 | la asuncion
# Processing Record 114 of Set 7 | alice springs
# Processing Record 115 of Set 7 | hambantota
# Processing Record 116 of Set 7 | los llanos de aridane
# Processing Record 117 of Set 7 | nazilli
# Processing Record 118 of Set 7 | vaitape
# Processing Record 119 of Set 7 | pokrovsk
# Processing Record 120 of Set 7 | qaanaaq
# Processing Record 121 of Set 7 | harstad
# Processing Record 122 of Set 7 | salalah
# Processing Record 123 of Set 7 | halifax
# Processing Record 124 of Set 7 | xaghra
# Processing Record 125 of Set 7 | faanui
# Processing Record 126 of Set 7 | olivehurst
# Processing Record 127 of Set 7 | airai
# Processing Record 128 of Set 7 | takayama
# Processing Record 129 of Set 7 | mataura
# Processing Record 130 of Set 7 | torbay
# City not found. Skipping...
# Processing Record 132 of Set 8 | kachug
# Processing Record 133 of Set 8 | hilo
# City not found. Skipping...
# Processing Record 135 of Set 9 | port blair
# Processing Record 136 of Set 9 | new norfolk
# Processing Record 137 of Set 9 | aksu
# Processing Record 138 of Set 9 | beringovskiy
# Processing Record 139 of Set 9 | bandar-e lengeh
# Processing Record 140 of Set 9 | fairlie
# Processing Record 141 of Set 9 | laem sing
# City not found. Skipping...
# Processing Record 143 of Set 10 | richards bay
# Processing Record 144 of Set 10 | kilindoni
# Processing Record 145 of Set 10 | iqaluit
# Processing Record 146 of Set 10 | colon
# Processing Record 147 of Set 10 | buin
# Processing Record 148 of Set 10 | taoudenni
# Processing Record 149 of Set 10 | norman wells
# Processing Record 150 of Set 10 | upernavik
# Processing Record 151 of Set 10 | cayenne
# Processing Record 152 of Set 10 | gamba
# Processing Record 153 of Set 10 | provideniya
# Processing Record 154 of Set 10 | ostrovnoy
# Processing Record 155 of Set 10 | kavieng
# Processing Record 156 of Set 10 | zaysan
# City not found. Skipping...
# Processing Record 158 of Set 11 | mullovka
# Processing Record 159 of Set 11 | pevek
# Processing Record 160 of Set 11 | tashara
# Processing Record 161 of Set 11 | lata
# City not found. Skipping...
# Processing Record 163 of Set 12 | mocuba
# Processing Record 164 of Set 12 | terra santa
# Processing Record 165 of Set 12 | lebu
# City not found. Skipping...
# Processing Record 167 of Set 13 | san carlos de bariloche
# Processing Record 168 of Set 13 | honiara
# Processing Record 169 of Set 13 | pisco
# Processing Record 170 of Set 13 | gravdal
# Processing Record 171 of Set 13 | saint-pierre
# Processing Record 172 of Set 13 | mehamn
# City not found. Skipping...
# Processing Record 174 of Set 14 | souillac
# City not found. Skipping...
# Processing Record 176 of Set 15 | cherskiy
# Processing Record 177 of Set 15 | rio grande
# Processing Record 178 of Set 15 | mogadishu
# Processing Record 179 of Set 15 | kirakira
# Processing Record 180 of Set 15 | pillaro
# Processing Record 181 of Set 15 | kloulklubed
# Processing Record 182 of Set 15 | san jose
# Processing Record 183 of Set 15 | aykhal
# City not found. Skipping...
# Processing Record 185 of Set 16 | floro
# Processing Record 186 of Set 16 | hovd
# Processing Record 187 of Set 16 | biak
# Processing Record 188 of Set 16 | dakar
# Processing Record 189 of Set 16 | palmas
# Processing Record 190 of Set 16 | saint-philippe
# Processing Record 191 of Set 16 | sambava
# Processing Record 192 of Set 16 | oskemen
# Processing Record 193 of Set 16 | esmeraldas
# Processing Record 194 of Set 16 | takoradi
# Processing Record 195 of Set 16 | russell
# Processing Record 196 of Set 16 | chapais
# Processing Record 197 of Set 16 | pec
# Processing Record 198 of Set 16 | vila velha
# Processing Record 199 of Set 16 | bardiyah
# Processing Record 200 of Set 16 | naze
# Processing Record 201 of Set 16 | gizo
# Processing Record 202 of Set 16 | ilulissat
# Processing Record 203 of Set 16 | constitucion
# City not found. Skipping...
# Processing Record 205 of Set 17 | east london
# Processing Record 206 of Set 17 | san patricio
# Processing Record 207 of Set 17 | balkhash
# Processing Record 208 of Set 17 | fairbanks
# Processing Record 209 of Set 17 | ponta delgada
# Processing Record 210 of Set 17 | bay roberts
# Processing Record 211 of Set 17 | hellvik
# Processing Record 212 of Set 17 | powell river
# City not found. Skipping...
# Processing Record 214 of Set 18 | siauliai
# Processing Record 215 of Set 18 | casimiro de abreu
# Processing Record 216 of Set 18 | derzhavinsk
# Processing Record 217 of Set 18 | port elizabeth
# Processing Record 218 of Set 18 | asilah
# Processing Record 219 of Set 18 | rawson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 222 of Set 20 | thompson
# Processing Record 223 of Set 20 | leningradskiy
# Processing Record 224 of Set 20 | natitingou
# Processing Record 225 of Set 20 | pangnirtung
# Processing Record 226 of Set 20 | batsfjord
# Processing Record 227 of Set 20 | mamontovo
# Processing Record 228 of Set 20 | carnarvon
# City not found. Skipping...
# Processing Record 230 of Set 21 | ilheus
# Processing Record 231 of Set 21 | razgrad
# Processing Record 232 of Set 21 | marsabit
# Processing Record 233 of Set 21 | ihosy
# Processing Record 234 of Set 21 | itaituba
# Processing Record 235 of Set 21 | tilichiki
# Processing Record 236 of Set 21 | santa maria
# Processing Record 237 of Set 21 | yellowknife
# Processing Record 238 of Set 21 | ribeira grande
# Processing Record 239 of Set 21 | nueve de julio
# City not found. Skipping...
# Processing Record 241 of Set 22 | alta floresta
# Processing Record 242 of Set 22 | lianran
# Processing Record 243 of Set 22 | pidhaytsi
# Processing Record 244 of Set 22 | andilamena
# City not found. Skipping...
# Processing Record 246 of Set 23 | bathsheba
# Processing Record 247 of Set 23 | carutapera
# Processing Record 248 of Set 23 | poum
# Processing Record 249 of Set 23 | asau
# Processing Record 250 of Set 23 | seymchan
# Processing Record 251 of Set 23 | bandiagara
# City not found. Skipping...
# Processing Record 253 of Set 24 | fort saint james
# Processing Record 254 of Set 24 | harboore
# Processing Record 255 of Set 24 | callaway
# Processing Record 256 of Set 24 | skjervoy
# Processing Record 257 of Set 24 | bozoum
# Processing Record 258 of Set 24 | aloleng
# Processing Record 259 of Set 24 | paamiut
# Processing Record 260 of Set 24 | santa luzia
# Processing Record 261 of Set 24 | luderitz
# Processing Record 262 of Set 24 | zonguldak
# Processing Record 263 of Set 24 | voznesenye
# Processing Record 264 of Set 24 | tual
# Processing Record 265 of Set 24 | merauke
# Processing Record 266 of Set 24 | bayan
# Processing Record 267 of Set 24 | nyurba
# Processing Record 268 of Set 24 | khatanga
# Processing Record 269 of Set 24 | henties bay
# Processing Record 270 of Set 24 | enugu
# Processing Record 271 of Set 24 | coquimbo
# Processing Record 272 of Set 24 | soyo
# Processing Record 273 of Set 24 | palma di montechiaro
# Processing Record 274 of Set 24 | santa rosa
# Processing Record 275 of Set 24 | qaqortoq
# Processing Record 276 of Set 24 | sao joao da barra
# Processing Record 277 of Set 24 | lyngseidet
# Processing Record 278 of Set 24 | lompoc
# Processing Record 279 of Set 24 | ingleside
# Processing Record 280 of Set 24 | padang
# Processing Record 281 of Set 24 | antofagasta
# Processing Record 282 of Set 24 | natal
# Processing Record 283 of Set 24 | karratha
# Processing Record 284 of Set 24 | uvira
# Processing Record 285 of Set 24 | charlestown
# Processing Record 286 of Set 24 | ponta do sol
# Processing Record 287 of Set 24 | saint-denis
# Processing Record 288 of Set 24 | alekseyevsk
# Processing Record 289 of Set 24 | avera
# Processing Record 290 of Set 24 | mount isa
# Processing Record 291 of Set 24 | dwarka
# Processing Record 292 of Set 24 | sokoni
# Processing Record 293 of Set 24 | ust-ishim
# Processing Record 294 of Set 24 | ishigaki
# Processing Record 295 of Set 24 | aksarka
# Processing Record 296 of Set 24 | san javier
# Processing Record 297 of Set 24 | zlobin
# Processing Record 298 of Set 24 | porto novo
# Processing Record 299 of Set 24 | kavaratti
# Processing Record 300 of Set 24 | ola
# Processing Record 301 of Set 24 | chulman
# Processing Record 302 of Set 24 | evensk
# Processing Record 303 of Set 24 | matagami
# Processing Record 304 of Set 24 | bom jesus da lapa
# Processing Record 305 of Set 24 | dalvik
# Processing Record 306 of Set 24 | grand rapids
# Processing Record 307 of Set 24 | garcia
# City not found. Skipping...
# Processing Record 309 of Set 25 | harper
# Processing Record 310 of Set 25 | novyy urengoy
# Processing Record 311 of Set 25 | sagar
# Processing Record 312 of Set 25 | kruisfontein
# Processing Record 558 of Set 51 | kununurra
# Processing Record 559 of Set 51 | keokuk
# Processing Record 560 of Set 51 | amuntai
# City not found. Skipping...
# Processing Record 562 of Set 52 | kargasok
# Processing Record 563 of Set 52 | walvis bay
# Processing Record 564 of Set 52 | andenes
# Processing Record 565 of Set 52 | semporna
# Processing Record 566 of Set 52 | hualmay
# Processing Record 567 of Set 52 | inuvik
# Processing Record 568 of Set 52 | podyuga
# Processing Record 569 of Set 52 | lithakia
# Processing Record 570 of Set 52 | khor
# Processing Record 571 of Set 52 | annau
# Processing Record 572 of Set 52 | morondava
# Processing Record 573 of Set 52 | zelenoborskiy
# Processing Record 574 of Set 52 | terracina
# Processing Record 575 of Set 52 | ambatolampy
# Processing Record 576 of Set 52 | petropavlovskoye
# Processing Record 577 of Set 52 | manggar
# Processing Record 578 of Set 52 | khash
# Processing Record 579 of Set 52 | ryotsu
# Processing Record 580 of Set 52 | marawi
# Processing Record 581 of Set 52 | mata
# Processing Record 582 of Set 52 | pacific grove
# Processing Record 583 of Set 52 | katangli
# Processing Record 584 of Set 52 | sept-iles
# Processing Record 585 of Set 52 | limon
# Processing Record 586 of Set 52 | kurilsk
# Processing Record 587 of Set 52 | axim
# Processing Record 588 of Set 52 | lerwick
# Processing Record 589 of Set 52 | santa fe
# Processing Record 590 of Set 52 | san antonio
# Processing Record 591 of Set 52 | faya
# Processing Record 592 of Set 52 | doka
# Processing Record 593 of Set 52 | el alto
# Processing Record 594 of Set 52 | muyezerskiy
# City not found. Skipping...
# Processing Record 596 of Set 53 | ust-nera
# Processing Record 597 of Set 53 | japura
# Processing Record 598 of Set 53 | toumodi
# Processing Record 599 of Set 53 | la ronge
# Processing Record 600 of Set 53 | sabha
# Processing Record 601 of Set 53 | dibulla
# Processing Record 602 of Set 53 | sisimiut
# Processing Record 603 of Set 53 | asmara
# Processing Record 604 of Set 53 | deputatskiy
# Processing Record 605 of Set 53 | mutoko
# Processing Record 606 of Set 53 | progreso
# Processing Record 607 of Set 53 | chama
# Processing Record 608 of Set 53 | sao jose da coroa grande
# Processing Record 609 of Set 53 | dourbali
# Processing Record 610 of Set 53 | karlstadt
# City not found. Skipping...
# Processing Record 612 of Set 54 | luganville
# Processing Record 613 of Set 54 | boa vista
# Processing Record 614 of Set 54 | raudeberg
# Processing Record 615 of Set 54 | iranshahr
# City not found. Skipping...
# Processing Record 617 of Set 55 | muzaffarpur
# Processing Record 618 of Set 55 | muros
# Processing Record 619 of Set 55 | trairi
# Processing Record 620 of Set 55 | huari
# Processing Record 621 of Set 55 | gueret
# Processing Record 622 of Set 55 | vostok
# Processing Record 623 of Set 55 | san felipe
# Processing Record 624 of Set 55 | taganak
# Processing Record 625 of Set 55 | eagle pass
# Processing Record 626 of Set 55 | atar
# Processing Record 627 of Set 55 | linxia
# Processing Record 628 of Set 55 | vilhena
# Processing Record 629 of Set 55 | fuling
# Processing Record 630 of Set 55 | okha
# Processing Record 631 of Set 55 | kodinsk
# Processing Record 632 of Set 55 | haines junction
# Processing Record 633 of Set 55 | korla
# City not found. Skipping...
#
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": city_name,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Lat" : lat,
    "Lon" : lon,
    "Max Temp" : max_temp,
    "Wind Speed" : wind_speed    
}

weather_data = pd.DataFrame(weather_dict)

weather_data.to_csv("cities.csv", index=True, header=True)

weather_data
# Out:
#                 City  Cloudiness Country        Date  Humidity    Lat     Lon  \
# 0             Barrow          20      US  1581711533        96  71.29 -156.79
# 1        Port-Gentil          20      GA  1581711733        88  -0.72    8.78
# 2         Sao Filipe         100      CV  1581711733        55  14.90  -24.50
# 3              Buala         100      SB  1581711733        84  -8.14  159.59
# 4          Gushikawa          75      JP  1581711733        88  26.35  127.87
# ..               ...         ...     ...         ...       ...    ...     ...
# 574           Fuling         100      CN  1581711902        96  29.70  107.39
# 575             Okha          98      RU  1581711902        86  53.57  142.95
# 576          Kodinsk          11      RU  1581711903        96  58.69   99.18
# 577  Haines Junction          96      CA  1581711903        95  60.75 -137.51
# 578            Korla         100      CN  1581711903        51  41.76   86.15
#
#      Max Temp  Wind Speed
# 0      -34.60        5.82
# 1       82.40        2.24
# 2       74.39       17.81
# 3       79.36        9.66
# 4       73.40        6.93
# ..        ...         ...
# 574     43.77        3.74
# 575     -5.39       16.31
# 576      5.38        4.41
# 577     -5.87        3.67
# 578     16.00        1.99
#
# [579 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.figure(1)

ax = plt.gca()

weather_data.plot(kind='scatter', x='Lat', y='Max Temp', alpha=0.7, edgecolors='Black', s = 30, ax=ax)

plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()

# Save the Figure
plt.savefig("images/Fig1.png")

# Show the Figure
plt.show()

# %% [markdown]
# Here, the data points appear to be tight indicating a high correlation between our variables - latitude and maximum temperature.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.figure(2)

ax = plt.gca()

weather_data.plot(kind='scatter', x='Lat', y='Humidity', alpha=0.7, edgecolors='Black', s = 30, ax=ax)

plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# Save the Figure
plt.savefig("images/Fig2.png")

# Show the Figure
plt.show()

# %% [markdown]
# The scatter plot tells us that are randomly selected sample data show no correlation for our variables humidity and latitude.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.figure(3)

ax = plt.gca()

weather_data.plot(kind='scatter', x='Lat', y='Cloudiness', alpha=0.7, edgecolors='Black', s = 30, ax=ax)

plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# Save the Figure
plt.savefig("images/Fig3.png")

# Show the Figure
plt.show()

# %% [markdown]
# This graph tells us that there is no correlation between our variables - latitude and cloudiness. There doesn't seem to be a pattern on how the data points lie and does not seem to go in any particular direction either.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.figure(4)

ax = plt.gca()

weather_data.plot(kind='scatter', x='Lat', y='Wind Speed', alpha=0.7, edgecolors='Black', s = 30, ax=ax)

plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()

# Save the Figure
plt.savefig("images/Fig4.png")

# Show the Figure
plt.show()

# %% [markdown]
# This scatter plot tells us how the wind speed is affected by Latitude.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere_data = weather_data[weather_data['Lat'] >= 0]
southern_hemisphere_data = weather_data[weather_data['Lat'] < 0]

# %%
southern_hemisphere_data
# Out:
#                          City  Cloudiness Country        Date  Humidity  \
# 1                 Port-Gentil          20      GA  1581711733        88
# 3                       Buala         100      SB  1581711733        84
# 5                   Esperance          75      AU  1581711734        63
# 9                  Mossamedes          26      AO  1581711735        74
# 11            Arraial do Cabo          75      BR  1581711735        83
# ..                        ...         ...     ...         ...       ...
# 555  Sao Jose da Coroa Grande          17      BR  1581711897        77
# 558                Luganville          75      VU  1581711643        94
# 564                    Trairi         100      BR  1581711899        94
# 565                     Huari          48      PE  1581711900        59
# 573                   Vilhena          40      BR  1581711902        55
#
#        Lat     Lon  Max Temp  Wind Speed
# 1    -0.72    8.78     82.40        2.24
# 3    -8.14  159.59     79.36        9.66
# 5   -33.87  121.90     66.20       12.75
# 9   -15.20   12.15     75.65        8.21
# 11  -22.97  -42.03     78.80        5.82
# ..     ...     ...       ...         ...
# 555  -8.90  -35.15     81.32       13.98
# 558 -15.53  167.17     78.80        3.36
# 564  -3.28  -39.27     75.94        2.73
# 565  -9.33  -77.23     54.32        9.26
# 573 -12.74  -60.15     86.00        9.17
#
# [180 rows x 9 columns]

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
## Convert to floats and store Lat and Max Temp as x and y values
x_values = northern_hemisphere_data['Lat'].astype('float')
y_values = northern_hemisphere_data['Max Temp'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: -0.8521887241682629

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
## Convert to floats and store Lat and Max Temp as x and y values
x_values = southern_hemisphere_data['Lat'].astype('float')
y_values = southern_hemisphere_data['Max Temp'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq  = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,73),fontsize=14,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.38235783632922327

# %% [markdown]
# <b>Analysis: Max Temp vs. Latitude Linear Regression</b>
# >This scatter plot tells us how max temperature is affected by Latitude.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Lat and Max Temp as x and y values
x_values = northern_hemisphere_data['Lat'].astype('float')
y_values = northern_hemisphere_data['Humidity'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq2 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq2,(45,10),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.36659916188399194

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Lat and Max Temp as x and y values
x_values = southern_hemisphere_data['Lat'].astype('float')
y_values = southern_hemisphere_data['Humidity'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq2 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq2,(-55,32),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Humidity')

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.2869805401253556

# %% [markdown]
# <b>Analysis: Humidity vs. Latitude Linear Regression</b>
# >This scatter plot tells us how max temperature is affected by Latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Lat and Max Temp as x and y values
x_values = northern_hemisphere_data['Lat'].astype('float')
y_values = northern_hemisphere_data['Cloudiness'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq2 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq2,(45,13),fontsize=13,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.3506749398334484

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
## Convert to floats and store Lat and Max Temp as x and y values
x_values = southern_hemisphere_data['Lat'].astype('float')
y_values = southern_hemisphere_data['Cloudiness'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq2 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq2,(-55,28),fontsize=13,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.2565349597603468

# %% [markdown]
# <b>Analysis: Cloudiness vs. Latitude Linear Regression</b>
# >This scatter plot tells us how max temperature is affected by Latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Convert to floats and store Lat and Max Temp as x and y values
x_values = northern_hemisphere_data['Lat'].astype('float')
y_values = northern_hemisphere_data['Wind Speed'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq2 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq2,(0,30),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.10198080356515064

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
## Convert to floats and store Lat and Max Temp as x and y values
x_values = southern_hemisphere_data['Lat'].astype('float')
y_values = southern_hemisphere_data['Wind Speed'].astype('float')

# Run linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq2 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq2,(-25,25),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

# Print r square value
print(f"The r-squared is: {rvalue}")

# Show plot
plt.show()
# Out:
# The r-squared is: -0.3063063354190237

# %% [markdown]
# <b>Analysis: Cloudiness vs. Latitude Linear Regression</b>
# >This scatter plot tells us how max temperature is affected by Latitude.
